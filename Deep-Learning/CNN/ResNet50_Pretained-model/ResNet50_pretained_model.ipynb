# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# import pretained model VGG16
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
from tensorflow.keras.preprocessing import image
from keras.applications.resnet50 import ResNet50
model=ResNet50(weights='imagenet')

# %%
# load images and preprocess
imagepaths=["/content/dog.10021.jpg","/content/chair.webp","/content/cat.jpg"]
for curr_imagepath in imagepaths:
  imagepath=curr_imagepath
  img=image.load_img(imagepath,target_size=(224,224))
  x=image.img_to_array(img)
  x=np.expand_dims(x,axis=0)
  x=preprocess_input(x)
  plt.imshow(img)
  plt.axis("off")
  plt.show()

  pred = model.predict(x,verbose=0)
  print(f"Predictions for {imagepath}:\n")
  for _, label, score in decode_predictions(pred, top=5)[0]:
       print(f"{label:25} {score:.4f}")
  print("-" * 50)
# Out:
# Predictions for /content/dog.10021.jpg:
#
# malamute                  0.9709
# Eskimo_dog                0.0140
# Siberian_husky            0.0115
# Tibetan_mastiff           0.0024
# collie                    0.0002
# --------------------------------------------------
# Predictions for /content/chair.webp:
#
# cowboy_hat                0.2052
# barber_chair              0.1905
# rocking_chair             0.1283
# sombrero                  0.1092
# folding_chair             0.0489
# --------------------------------------------------
# Predictions for /content/cat.jpg:
#
# hare                      0.7371
# fox_squirrel              0.1005
# coyote                    0.0451
# wood_rabbit               0.0245
# Airedale                  0.0145
# --------------------------------------------------
