# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=fetch_california_housing()
# features
X=pd.DataFrame(df.data,columns=df.feature_names)

# target
y=df.target
# y

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
# from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model=model = XGBRegressor(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    random_state=42
)

# model=RandomForestRegressor(random_state=42)
# model=LinearRegression()
# model=DecisionTreeRegressor(random_state=42)
# model=Ridge(alpha=1.0)
# model=Lasso(alpha=1.0)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
# r2adj=1-((1-r2**2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# print(f"Radj-squared: {r2adj}")
# Out:
# Mean Squared Error: 0.21144600412758702
# R-squared: 0.8389032054191725

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred)

# Perfect prediction line
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    'r--'
)

plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values")
plt.show()

# %%
plt.scatter(X['AveBedrms'],y*100000)
plt.xlabel("Average Rooms")
plt.ylabel("Med House Value($)")
plt.title("Average Rooms vs Med House Value")
plt.show()
